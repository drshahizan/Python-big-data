# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/Python-big-data/blob/main/Assignment%202/team%208/Lab6_modin.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Install modin
# !pip install modin[all]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 970 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 12.2 MB 49.8 MB/s
# ...
#      |████████████████████████████████| 57.4 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 1.8 MB 60.4 MB/s
# ...
#      |████████████████████████████████| 68 kB 6.9 MB/s
# ...
#      |████████████████████████████████| 132 kB 75.4 MB/s
# ...
#      |████████████████████████████████| 102 kB 43.6 MB/s
# ...
#      |████████████████████████████████| 117 kB 73.8 MB/s
# ...
#      |████████████████████████████████| 439 kB 69.5 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 53.3 MB/s
# ...
#      |████████████████████████████████| 121 kB 54.8 MB/s
# ...
#      |████████████████████████████████| 9.8 MB 61.3 MB/s
# ...
#      |████████████████████████████████| 423 kB 59.6 MB/s
# ...
#      |████████████████████████████████| 363 kB 60.1 MB/s
# ...
#      |████████████████████████████████| 133 kB 59.0 MB/s
# ...

# %%
import numpy as np
import time
import pandas as pd
import modin.pandas as md

# %%
#Create an array of random integers
arr =np.random.randint(low=10,high=1000,size=(2**15,2**10))
#Save it as a csv file
np.savetxt("data.csv", arr, delimiter=",")

# %%
#Read data.csv file using Pandas
# %time p_df = pd.read_csv("data.csv")
# Out:
# CPU times: user 8.51 s, sys: 715 ms, total: 9.23 s
# Wall time: 9.57 s

# %%
#Read data.csv file using Modin
# %time m_df = md.read_csv("data.csv")
# Out:
# ...
# To remove this warning, run the following python code before doing dataframe operations:
#
#     import ray
#     ray.init(runtime_env={'env_vars': {'__MODIN_AUTOIMPORT_PANDAS__': '1'}})
#
# ...
# 2022-12-29 04:08:27,077	INFO worker.py:1529 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# CPU times: user 1.98 s, sys: 766 ms, total: 2.75 s
# Wall time: 18 s

# %% [markdown]
# ***Mean operation***

# %%
#Compute mean of each numerical column using Pandas
# %time p_df.mean(axis=0)
# Out:
# CPU times: user 105 ms, sys: 1.66 ms, total: 106 ms
# Wall time: 108 ms
# 6.540000000000000000e+02      503.263161
# 6.370000000000000000e+02      503.932554
# 1.640000000000000000e+02      501.901852
# 9.070000000000000000e+02      503.256417
# 7.450000000000000000e+02      503.875088
#                                  ...
# 9.450000000000000000e+02.2    503.323099
# 1.580000000000000000e+02.2    504.390179
# 8.820000000000000000e+02      504.911313
# 2.090000000000000000e+02.1    504.876949
# 3.860000000000000000e+02.1    502.952086
# Length: 1024, dtype: float64

# %%
# %time m_df.mean(axis=0)
# Out:
# CPU times: user 31.9 ms, sys: 2.66 ms, total: 34.6 ms
# Wall time: 44.2 ms
# 6.540000000000000000e+02      503.263161
# 6.370000000000000000e+02      503.932554
# 1.640000000000000000e+02      501.901852
# 9.070000000000000000e+02      503.256417
# 7.450000000000000000e+02      503.875088
#                                  ...
# 9.450000000000000000e+02.2    503.323099
# 1.580000000000000000e+02.2    504.390179
# 8.820000000000000000e+02      504.911313
# 2.090000000000000000e+02.1    504.876949
# 3.860000000000000000e+02.1    502.952086
# Length: 1024, dtype: float64

# %% [markdown]
# ***Concatenation***

# %%
# %time pd.concat([p_df, p_df], axis=0)
# Out:
# CPU times: user 146 ms, sys: 31.2 ms, total: 177 ms
# Wall time: 182 ms
#        6.540000000000000000e+02  6.370000000000000000e+02  \
# 0                         934.0                     911.0
# 1                         777.0                     148.0
# 2                         481.0                     964.0
# 3                         275.0                     956.0
# 4                         960.0                     194.0
# ...                         ...                       ...
# 32762                     876.0                     660.0
# 32763                     342.0                     588.0
# 32764                     462.0                     443.0
# 32765                     951.0                     662.0
# 32766                     977.0                     181.0
#
#        1.640000000000000000e+02  9.070000000000000000e+02  \
# 0                         195.0                     928.0
# 1                         799.0                     609.0
# ...

# %%
# %time md.concat([m_df, m_df], axis=0)
# Out:
# CPU times: user 16.2 ms, sys: 1.02 ms, total: 17.2 ms
# Wall time: 19.7 ms
#        6.540000000000000000e+02  6.370000000000000000e+02  \
# 0                         934.0                     911.0
# 1                         777.0                     148.0
# 2                         481.0                     964.0
# 3                         275.0                     956.0
# 4                         960.0                     194.0
# ...                         ...                       ...
# 32762                     876.0                     660.0
# 32763                     342.0                     588.0
# 32764                     462.0                     443.0
# 32765                     951.0                     662.0
# 32766                     977.0                     181.0
#
#        1.640000000000000000e+02  9.070000000000000000e+02  \
# 0                         195.0                     928.0
# 1                         799.0                     609.0
# ...

# %% [markdown]
# ***applymap() method ***

# %%
# %time p_df.applymap(lambda i:i*2)
# Out:
# CPU times: user 9.03 s, sys: 208 ms, total: 9.24 s
# Wall time: 9.44 s
#        6.540000000000000000e+02  6.370000000000000000e+02  \
# 0                        1868.0                    1822.0
# 1                        1554.0                     296.0
# 2                         962.0                    1928.0
# 3                         550.0                    1912.0
# 4                        1920.0                     388.0
# ...                         ...                       ...
# 32762                    1752.0                    1320.0
# 32763                     684.0                    1176.0
# 32764                     924.0                     886.0
# 32765                    1902.0                    1324.0
# 32766                    1954.0                     362.0
#
#        1.640000000000000000e+02  9.070000000000000000e+02  \
# 0                         390.0                    1856.0
# 1                        1598.0                    1218.0
# ...

# %%
#Element-wise multiplication of each element by 2 using Pandas
# %time m_df.applymap(lambda i:i*2)
# Out:
# CPU times: user 6.8 ms, sys: 1.17 ms, total: 7.98 ms
# Wall time: 10.8 ms
#        6.540000000000000000e+02  6.370000000000000000e+02  \
# 0                        1868.0                    1822.0
# 1                        1554.0                     296.0
# 2                         962.0                    1928.0
# 3                         550.0                    1912.0
# 4                        1920.0                     388.0
# ...                         ...                       ...
# 32762                    1752.0                    1320.0
# 32763                     684.0                    1176.0
# 32764                     924.0                     886.0
# 32765                    1902.0                    1324.0
# 32766                    1954.0                     362.0
#
#        1.640000000000000000e+02  9.070000000000000000e+02  \
# 0                         390.0                    1856.0
# 1                        1598.0                    1218.0
# ...
