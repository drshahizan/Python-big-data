# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/Python-big-data/blob/main/assignment/ass6/hpdp/HD/Assignment6_HD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 6 : Mastering Big Data Handling

# %% [markdown]
# #### Group : HD
# #### Group Members
# #### 1. WAN AMIRUL HAFIQ BIN WAN HUZAINI A21EC0141
# #### 2. ALYA DAMIA BINTI HUZAIMY A21EC0159

# %% [markdown]
# ## 1. Dataset Selection
#
# This dataset shows Airline Flight Delay and Cancellation Data, January 2023 - August 2023 based on US Department of Transportation, Bureau of Transportation Statistics.
#
# Source: https://www.kaggle.com/datasets/patrickzel/flight-delay-and-cancellation-dataset-2019-2023/data

# %% [markdown]
# ![Screenshot 2023-12-06 at 9.25.18 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 2. Data Acquisition

# %% [markdown]
# The dataset is in csv format.
#
# Link : https://drive.google.com/file/d/1dEiOI8oRRfPwQDD29S-d9J8MUvnSb3qh/view?usp=share_link

# %% [markdown]
# ![Screenshot 2023-12-06 at 9.36.40 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 3. Loading the Dataset

# %% [markdown]
# 1. First, we mounted the G Drive to import the dataset
# - This step is specific to Google Colab and helps you mount your Google Drive to access files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Import necessary libraries
#
# - This code imports the necessary libraries for data manipulation and analysis.

# %%
import pandas as pd

# %% [markdown]
# - *pandas* is a powerful library for data manipulation and analysis. It provides data structures like DataFrame for working with structured data, and it includes a variety of functions for cleaning, transforming, and analyzing data.

# %% [markdown]
# 3. We need to load the dataset
# - Load your dataset using Pandas. df is a common convention for a DataFrame, which is a tabular data structure in Pandas.

# %%
file_path = '/content/drive/My Drive/2023.csv'
df = pd.read_csv(file_path)
df
# Out:
#             FL_DATE AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN  \
# 0        2023-06-04           9E     20363       4628    DSM
# 1        2023-06-01           9E     20363       4628    ROC
# 2        2023-06-02           9E     20363       4628    ROC
# 3        2023-06-01           9E     20363       4629    ITH
# 4        2023-06-02           9E     20363       4629    ITH
# ...             ...          ...       ...        ...    ...
# 4545417  2023-08-01           YX     20452       3406    EWR
# 4545418  2023-08-01           YX     20452       3405    EWR
# 4545419  2023-08-01           YX     20452       3404    EWR
# 4545420  2023-08-01           YX     20452       3403    CHS
# 4545421  2023-08-01           YX     20452       3401    ORD
#
#                  ORIGIN_CITY DEST                   DEST_CITY  CRS_DEP_TIME  \
# 0             Des Moines, IA  LGA                New York, NY          1033
# 1              Rochester, NY  LGA                New York, NY          1001
# ...

# %% [markdown]
# 4. Display the few first line of dataset

# %%
df.head()
# Out:
#       FL_DATE AIRLINE_CODE  DOT_CODE  FL_NUMBER ORIGIN          ORIGIN_CITY  \
# 0  2023-06-04           9E     20363       4628    DSM       Des Moines, IA
# 1  2023-06-01           9E     20363       4628    ROC        Rochester, NY
# 2  2023-06-02           9E     20363       4628    ROC        Rochester, NY
# 3  2023-06-01           9E     20363       4629    ITH  Ithaca/Cortland, NY
# 4  2023-06-02           9E     20363       4629    ITH  Ithaca/Cortland, NY
#
#   DEST     DEST_CITY  CRS_DEP_TIME  DEP_TIME  ...  AIR_TIME  DISTANCE  \
# 0  LGA  New York, NY          1033    1053.0  ...     134.0    1031.0
# 1  LGA  New York, NY          1001     956.0  ...      49.0     254.0
# 2  LGA  New York, NY          1001     956.0  ...      46.0     254.0
# 3  JFK  New York, NY          1452    1447.0  ...      46.0     189.0
# 4  JFK  New York, NY          1452    1448.0  ...      46.0     189.0
#
#    DELAY_DUE_CARRIER  DELAY_DUE_WEATHER  DELAY_DUE_NAS  DELAY_DUE_SECURITY  \
# ...

# %% [markdown]
# ## 4.  Strategies for Big Datasets

# %% [markdown]
# ###1. Load less data

# %% [markdown]
# 1. Select only specific columns needed

# %%
selected_columns = ["DEP_DELAY", "ARR_DELAY", "TAXI_OUT","CRS_DEP_TIME", "DEP_TIME","CRS_ARR_TIME", "ARR_TIME", "AIRLINE_CODE"]
df_selected = pd.read_csv(file_path, usecols=selected_columns)

# %% [markdown]
# 2. Print a first few line of selected column

# %%
df_selected.head()
# Out:
#   AIRLINE_CODE  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  CRS_ARR_TIME  \
# 0           9E          1033    1053.0       20.0      17.0          1415
# 1           9E          1001     956.0       -5.0      15.0          1119
# 2           9E          1001     956.0       -5.0       9.0          1119
# 3           9E          1452    1447.0       -5.0      11.0          1559
# 4           9E          1452    1448.0       -4.0      13.0          1559
#
#    ARR_TIME  ARR_DELAY
# 0    1439.0       24.0
# 1    1116.0       -3.0
# 2    1102.0      -17.0
# 3    1556.0       -3.0
# 4    1554.0       -5.0

# %% [markdown]
# ### 2. Process the data in smaller chunks

# %% [markdown]
# 1.  This step allows you to read the dataset in smaller chunks rather than loading the entire dataset into memory at once. The *chunksize* parameter specifies the number of rows to be read in each iteration.

# %%
chunk_size = 10000
chunks = pd.read_csv(file_path, usecols=selected_columns, chunksize=chunk_size)

# %% [markdown]
# 2. Display the first few rows of the first chunk

# %%
for chunk in chunks:
    print(chunk.head())
    break
# Out:
#   AIRLINE_CODE  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  CRS_ARR_TIME  \
# 0           9E          1033    1053.0       20.0      17.0          1415
# 1           9E          1001     956.0       -5.0      15.0          1119
# 2           9E          1001     956.0       -5.0       9.0          1119
# 3           9E          1452    1447.0       -5.0      11.0          1559
# 4           9E          1452    1448.0       -4.0      13.0          1559
#
#    ARR_TIME  ARR_DELAY
# 0    1439.0       24.0
# 1    1116.0       -3.0
# 2    1102.0      -17.0
# 3    1556.0       -3.0
# 4    1554.0       -5.0

# %% [markdown]
# - The code then iterates over the chunks using a *for* loop. In each iteration, it prints the first few rows of the current chunk using *chunk.head()*. The *break* statement is used to exit the loop after processing the first chunk. This is done for demonstration purposes to show the structure of the data in the first chunk.

# %% [markdown]
# ###3. Optimize Data Types:

# %% [markdown]
# 1. Fine-tune data types

# %%
df_optimized = pd.read_csv(file_path,usecols=selected_columns, dtype={"DEP_DELAY" :"float32", "ARR_DELAY":"float32", "TAXI_OUT":"float32","CRS_DEP_TIME":"int32", "DEP_TIME":"float32","CRS_ARR_TIME":"int32", "ARR_TIME":"float32"})

# %% [markdown]
# - The key aspect here is the *dtype* parameter, which allows you to specify the data types for specific columns. In this case, it's explicitly stating that certain column should be of type *int32*, and certain should be of type *float32*.

# %% [markdown]
# 2. Print the data types of each column

# %%
df_optimized.dtypes
# Out:
# AIRLINE_CODE     object
# CRS_DEP_TIME      int32
# DEP_TIME        float32
# DEP_DELAY       float32
# TAXI_OUT        float32
# CRS_ARR_TIME      int32
# ARR_TIME        float32
# ARR_DELAY       float32
# dtype: object

# %% [markdown]
# - Fine-tuning data types during the data loading phase is a strategy to optimize memory usage, enhance computational performance, and ensure compatibility with downstream analyses, ultimately contributing to more efficient and effective data processing.

# %% [markdown]
# ###4. Sampling

# %% [markdown]
# 1. Sample a fraction of the dataset. In this case, we use 10% of the data

# %%
sample_size = 0.1
df_selected_sampled = pd.read_csv(file_path, usecols=selected_columns).sample(frac=sample_size)

# %% [markdown]
# - Sampling a fraction of the dataset means selecting a subset of the data that represents a certain proportion or percentage of the entire dataset.

# %% [markdown]
# 2. Print the first few rows of the sampled dataset

# %%
df_selected_sampled.head()
# Out:
#         AIRLINE_CODE  CRS_DEP_TIME  DEP_TIME  DEP_DELAY  TAXI_OUT  \
# 696917            AS          1400    1353.0       -7.0      23.0
# 2474342           DL           540     552.0       12.0      13.0
# 3447176           9E           730     729.0       -1.0      21.0
# 4514643           WN          1920    1923.0        3.0      11.0
# 3934047           UA           754     751.0       -3.0      32.0
#
#          CRS_ARR_TIME  ARR_TIME  ARR_DELAY
# 696917           2159    2141.0      -18.0
# 2474342           759     804.0        5.0
# 3447176          1020    1003.0      -17.0
# 4514643          2025    2023.0       -2.0
# 3934047           857     857.0        0.0

# %% [markdown]
# - This line simply prints the first few rows of the sampled DataFrame, providing a quick visual check to ensure that the sampling operation was successful and to get a glimpse of the sampled data.

# %% [markdown]
# ### 5. Parallelize with Dask

# %% [markdown]
# 1. Install Dask

# %%
# !pip install dask

# %% [markdown]
# - Dask is a parallel computing library that extends the capabilities of Pandas for handling larger-than-memory datasets.

# %% [markdown]
# 2. Import Dask

# %%
import dask.dataframe as dd

# %% [markdown]
# - This line imports the Dask dataframe module *dd* so that you can use Dask's dataframe functionalities. Dask dataframes are similar to Pandas dataframes but are designed to work with larger datasets that may not fit into memory.

# %% [markdown]
# 3. Read the Dataset using Dask

# %%
ddf = dd.read_csv(file_path)

# %% [markdown]
# - Dask dataframes can operate on larger-than-memory datasets by breaking them into smaller partitions that can be processed in parallel

# %% [markdown]
# 4. Perform Operations in Parallel

# %%
result = ddf.groupby('AIRLINE_CODE').DEP_DELAY.mean().compute()
result
# Out:
# AIRLINE_CODE
# 9E     8.575813
# AA    20.762315
# AS     7.080923
# B6    26.036402
# DL    13.156901
# F9    26.694103
# G4    17.762581
# HA    11.772293
# MQ     8.127928
# NK    22.534017
# OH     8.350298
# OO     9.360686
# UA    16.118146
# WN    13.171101
# YX     4.442943
# Name: DEP_DELAY, dtype: float64

# %% [markdown]
# - The code performs a groupby operation on the *AIRLINE_CODE* column of the Dask dataframe. It calculates the mean of the *DEP_DELAY* column within each group. The compute() function is then used to trigger the parallel execution of the computation and return the result as a Pandas dataframe (result).
#
# - The grouping and aggregation operations are performed in parallel, making use of Dask's ability to distribute computations across multiple cores or even on a cluster for larger datasets.

# %% [markdown]
# > Dask can be used to read and process a large dataset in a distributed and parallelized manner, particularly when dealing with operations like grouping and aggregation. It's a powerful tool for efficiently handling big data that may not fit into memory using traditional Pandas workflows

# %% [markdown]
# ## 5. Comparative Analysis

# %% [markdown]
# 1. Install memory-profiler

# %%
# !pip install memory-profiler

# %% [markdown]
# - *Memory-profiler* is a tool used to profile and analyze the memory usage of Python code

# %% [markdown]
# 2. Load the Memory Profiler Extension

# %%
# %load_ext memory_profiler

# %% [markdown]
# - The *%load_ext* magic command is used to load the extension, allowing you to use memory profiling capabilities

# %% [markdown]
# 3. Profile Memory Usage

# %%
# %memit df = pd.read_csv(file_path)
print("Memory Usage:")
print(df.memory_usage().sum())
# Out:
# peak memory: 6917.80 MiB, increment: 3158.55 MiB
# Memory Usage:
# 1199991536

# %% [markdown]
# - *%memit* is a magic command that is used to profile the memory usage of a specific code block. In this case, it reads the CSV file specified by the *file_path* variable using Pandas *(pd.read_csv(file_path))* and assigns the result to the variable df.
#
# - The memory usage of the resulting dataframe *(df)* is then printed using print*("Memory Usage:")* followed by print *(df.memory_usage().sum())*. This provides information about the total memory usage of the dataframe

# %% [markdown]
# 4. Profile Computation Time

# %%
# %timeit df = pd.read_csv(file_path)
# Out:
# 23.1 s ± 1.5 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %% [markdown]
# - *%timeit* is a magic command that is used to profile the execution time of a specific code block. In this case, it measures the time taken to execute the *pd.read_csv(file_path)* operation.
#
# - The result is printed automatically by *%timeit* and includes information such as the average time taken for the operation to complete.

# %% [markdown]
# > The *memory-profiler* and *%timeit* magic commands to profile the memory usage and computation time, respectively, of the operation of reading a CSV file into a Pandas dataframe. These tools are useful for identifying potential bottlenecks and optimizing code for better performance

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# > In handling big datasets, strategic approaches were employed to enhance efficiency and mitigate challenges. Loading essential portions of the dataset through column selection or conditional filtering optimizes memory usage, crucial for large datasets with limited RAM. Processing data in smaller, manageable chunks via chunking prevents memory issues, while fine-tuning data types minimizes memory consumption. Sampling methodologies provide insights from a subset, reducing computation time and offering a quick overview of data patterns. Leveraging Dask for parallel and distributed computing significantly accelerates operations, particularly in handling larger-than-memory datasets. These strategies collectively contribute to reduced memory usage, faster computation times, and optimized storage, addressing the complexities of managing extensive datasets effectively. The choice of strategies depends on specific use cases, but their combination proves valuable in enhancing overall big data handling efficiency.
